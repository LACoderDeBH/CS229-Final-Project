# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
"""
INFO:
101,332 Players with up to 20 features each (exluding year, including team)
if metric not reported for player, set to 0.0 by default
"""
batting_data_path = 'bsb_ref.csv'

df = pd.read_csv(batting_data_path)
df = df.fillna(0)  # fixing this could really help with results potentially

# %%
n = 3
temp = df[(df['name_common'] == 'Barry Bonds') 
          | (df['name_common'] == 'Kris Bryant')
          | (df['name_common'] == 'Nico Hoerner') 
          | (df['name_common'] == 'Ted Williams')]
temp = temp.groupby('name_common').filter(lambda years : len(years) >= n)
temp.head()

players = set(temp.name_common.values)
for player in players:
    temp[temp['name_common'] == player] = temp[temp['name_common'] == player].head(n=n)
temp = temp.dropna()   # sus af

temp
# Out:
#          name_common   age    mlb_ID  player_ID  year_ID team_ID  stint_ID  \
# 8789     Barry Bonds  21.0  111188.0  bondsba01   1986.0     PIT       1.0
# 8790     Barry Bonds  22.0  111188.0  bondsba01   1987.0     PIT       1.0
# 8791     Barry Bonds  23.0  111188.0  bondsba01   1988.0     PIT       1.0
# 11979    Kris Bryant  23.0  592178.0  bryankr01   2015.0     CHC       1.0
# 11980    Kris Bryant  24.0  592178.0  bryankr01   2016.0     CHC       1.0
# 11981    Kris Bryant  25.0  592178.0  bryankr01   2017.0     CHC       1.0
# 104121  Ted Williams  20.0  124341.0  willite01   1939.0     BOS       1.0
# 104122  Ted Williams  21.0  124341.0  willite01   1940.0     BOS       1.0
# 104123  Ted Williams  22.0  124341.0  willite01   1941.0     BOS       1.0
#
#        lg_ID     PA      G  ...  oppRpG_rep  pyth_exponent  pyth_exponent_rep  \
# 8789      NL  484.0  113.0  ...     4.00784          1.833              1.819
# ...

# %%
temp = temp.apply(lambda x : )

# %%
df_recent_players = df[df.year_ID >= 1975] 
df_probably_not_pitchers = df_recent_players[df_recent_players['PA'] >= 50]

players = list(set(df_probably_not_pitchers['name_common'])) # just a set of all players


def find_peers(player_data, columns, player, n=6):
    """
    Ideally:
        -Drop players who have played fewer than n years.
        -Drop years not in [1, n].
        -Normalize each metric for each year i in n.
        -Compute L2 norm between player and all others.
        -Return new dataframe containing player's peers in range [1, n]
    Currently:
        -Drop players who have played fewer than n years.
        -Drop years not in [1, n].
    Hopefully with a sufficiently large n, the players will all be similar enough.
    """
    # drop players years played < n
    veteran_player_data = player_data.groupby('name_common').filter(lambda years: len(years) >= n)
    
    
    
    # drop years not in [1, n]
    
    # normalize each metric for each year i in n
    year_data = veteran_player_data.groupby('year_ID')
    
    
    # compute Ld dorm between player and all others
    # return new dataframe containing player's peers in range [1, n] 
    
    player_data = player_data.groupby('name_common').filter(lambda years : len(years) >= n)
    players = set(temp.name_common.values)
    for p in players:
        player_data[player_data['name_common'] == p] /
            = player_data[player_data['name_common'] == p].head(n=n)
    player_data = player_data.dropna()   # sus af
    return player_data

    

temp
    

temp = find_peers(pd.DataFrame.copy(df), list(df.columns.values), 'David Aardsma', n=6)
df.head()
