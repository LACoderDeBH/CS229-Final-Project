# %% [markdown]
# ## Data processing

# %% [markdown]
# ### Include only position players appearing after 1975

# %%
import pandas as pd
df = pd.read_csv('bsb_ref.csv')
df = df.fillna(df.mean())     
df = df[df.year_ID >= 1975]    # drop rows before 1975
df = df[df.pitcher == 'N']     # drop pitchers
df = df.sort_values(by=['name_common', 'year_ID'])   # sort values by name

# player MLB ID => player name
playerNameToID = {row['mlb_ID']: row['name_common'] for __, row in df.iterrows()}

df.head()
# Out:
#       name_common   age    mlb_ID  player_ID  year_ID team_ID  stint_ID lg_ID  \
# 27449  A.J. Ellis  27.0  454560.0  ellisaj01     2008     LAD         1    NL
# 27450  A.J. Ellis  28.0  454560.0  ellisaj01     2009     LAD         1    NL
# 27451  A.J. Ellis  29.0  454560.0  ellisaj01     2010     LAD         1    NL
# 27452  A.J. Ellis  30.0  454560.0  ellisaj01     2011     LAD         1    NL
# 27453  A.J. Ellis  31.0  454560.0  ellisaj01     2012     LAD         1    NL
#
#           PA    G  ...  oppRpG_rep  pyth_exponent  pyth_exponent_rep  \
# 27449    3.0    4  ...     4.61849          1.876              1.886
# 27450   10.0    8  ...     4.47002          1.858              1.869
# 27451  128.0   44  ...     4.29053          1.859              1.851
# 27452  103.0   31  ...     4.05168          1.836              1.822
# 27453  505.0  133  ...     4.17112          1.852              1.838
#
#        waa_win_perc  waa_win_perc_off  waa_win_perc_def  waa_win_perc_rep  \
# 27449        0.4799            0.4799            0.5020            0.4976
# 27450        0.4764            0.4764            0.5026            0.4959
# 27451        0.4994            0.5042            0.5007            0.4903
# 27452        0.5055            0.5126            0.4988            0.4885
# 27453        0.5137            0.5121            0.5085            0.4871
#
#        OPS_plus   TOB_lg    TB_lg
# 27449 -100.0000    1.009    1.268
# 27450  -45.6488    3.320    4.127
# 27451   91.0563   40.498   43.783
# 27452  117.1384   32.762   33.668
# 27453  117.8717  160.279  171.865
#
# [5 rows x 49 columns]

# %%
for c in df.columns:
    print(c)
# Out:
# name_common
# age
# mlb_ID
# player_ID
# year_ID
# team_ID
# stint_ID
# lg_ID
# PA
# G
# Inn
# runs_bat
# runs_br
# runs_dp
# runs_field
# runs_infield
# runs_outfield
# runs_catcher
# runs_good_plays
# runs_defense
# runs_position
# runs_position_p
# runs_replacement
# runs_above_rep
# runs_above_avg
# runs_above_avg_off
# runs_above_avg_def
# WAA
# WAA_off
# WAA_def
# WAR
# WAR_def
# WAR_off
# WAR_rep
# salary
# pitcher
# teamRpG
# oppRpG
# oppRpPA_rep
# oppRpG_rep
# pyth_exponent
# pyth_exponent_rep
# waa_win_perc
# waa_win_perc_off
# waa_win_perc_def
# waa_win_perc_rep
# OPS_plus
# TOB_lg
# TB_lg

# %% [markdown]
# ### Filter out players who appeared in 2012-2017

# %%
df_2012 = pd.DataFrame(columns=df.columns)
df_2013 = pd.DataFrame(columns=df.columns)
df_2014 = pd.DataFrame(columns=df.columns)
df_2015 = pd.DataFrame(columns=df.columns)
df_2016 = pd.DataFrame(columns=df.columns)
df_2017 = pd.DataFrame(columns=df.columns)

# only consider players that appeared in 'years_appeared_in'
def eligible_player(player, years_appeared_in, years_of_interest):
    return set(years_of_interest).issubset(years_appeared_in)

players = sorted(list(set(df.name_common)))     # list of all players
years = [2012, 2013, 2014, 2015, 2016, 2017]
for player in players:
    player_rows = df[df.name_common == player]
    if not eligible_player(player, player_rows.year_ID.values, years):
        continue
    df_2012 = df_2012.append(player_rows[player_rows.year_ID == 2012].head(1))
    df_2013 = df_2013.append(player_rows[player_rows.year_ID == 2013].head(1))
    df_2014 = df_2014.append(player_rows[player_rows.year_ID == 2014].head(1))
    df_2015 = df_2015.append(player_rows[player_rows.year_ID == 2015].head(1))
    df_2016 = df_2016.append(player_rows[player_rows.year_ID == 2016].head(1))
    df_2017 = df_2017.append(player_rows[player_rows.year_ID == 2017].head(1))

# %%
df_2012.head()
# Out:
#         name_common   age    mlb_ID  player_ID year_ID team_ID stint_ID lg_ID  \
# 27453    A.J. Ellis  31.0  454560.0  ellisaj01    2012     LAD        1    NL
# 77094  A.J. Pollock  24.0  572041.0  polloaj01    2012     ARI        1    NL
# 43166    Aaron Hill  30.0  431094.0   hillaa01    2012     ARI        1    NL
# 26870    Adam Eaton  23.0  594809.0  eatonad02    2012     ARI        1    NL
# 48493    Adam Jones  26.0  430945.0  jonesad01    2012     BAL        1    AL
#
#           PA    G  ...  oppRpG_rep  pyth_exponent  pyth_exponent_rep  \
# 27453  505.0  133  ...     4.17112          1.852              1.838
# 77094   93.0   31  ...     4.19596          1.836              1.839
# 43166  668.0  156  ...     4.15897          1.857              1.837
# 26870  103.0   22  ...     4.15897          1.853              1.837
# 48493  697.0  162  ...     4.25092          1.871              1.850
#
#        waa_win_perc  waa_win_perc_off  waa_win_perc_def  waa_win_perc_rep  \
# 27453        0.5137            0.5121            0.5085            0.4871
# 77094        0.4876            0.4841            0.5031            0.4899
# 43166        0.5194            0.5207            0.5015            0.4858
# 26870        0.5187            0.5138            0.5073            0.4858
# 48493        0.5104            0.5188            0.4941            0.4830
#
#        OPS_plus   TOB_lg    TB_lg
# 27453  117.8717  160.279  171.865
# 77094   89.6687   30.397   33.947
# 43166  133.4968  220.377  255.232
# 26870  113.9719   33.701   35.624
# 48493  124.8557  225.201  269.374
#
# [5 rows x 49 columns]

# %% [markdown]
# ### Drop string-valued columns

# %%
# column name => column index
def get_col_indexes(columns):
    return {c: columns.get_loc(c) for c in list(columns)}

# %%
df_2012 = df_2012.select_dtypes(exclude=['object'])
df_2013 = df_2013.select_dtypes(exclude=['object'])
df_2014 = df_2014.select_dtypes(exclude=['object'])
df_2015 = df_2015.select_dtypes(exclude=['object'])
df_2016 = df_2016.select_dtypes(exclude=['object'])
df_2017 = df_2017.select_dtypes(exclude=['object'])

# assert (column name => column index) map is the same for all dataframes
cols_to_indexes_list = [get_col_indexes(df_2012.columns),
                        get_col_indexes(df_2013.columns),
                        get_col_indexes(df_2014.columns),
                        get_col_indexes(df_2015.columns),
                        get_col_indexes(df_2016.columns),
                        get_col_indexes(df_2017.columns)]
cols_to_indexes = cols_to_indexes_list[0]
for i in range(1, len(cols_to_indexes_list)):
    assert cols_to_indexes == cols_to_indexes_list[i]
ops_plus_index = cols_to_indexes['OPS_plus']
print('ops_plus_index = ', ops_plus_index)
# Out:
# ops_plus_index =  38

# %% [markdown]
# ### Convert to numpy arrays

# %%
np_2012 = df_2012.to_numpy()
np_2013 = df_2013.to_numpy()
np_2014 = df_2014.to_numpy()
np_2015 = df_2015.to_numpy()
np_2016 = df_2016.to_numpy()
np_2017 = df_2017.to_numpy()

print('np_2013 shape = ', np_2013.shape)
print('np_2014 shape = ', np_2014.shape)
print('np_2015 shape = ', np_2015.shape)
print('np_2016 shape = ', np_2016.shape)
print('np_2017 shape = ', np_2017.shape)
# Out:
# np_2013 shape =  (222, 41)
# np_2014 shape =  (222, 41)
# np_2015 shape =  (222, 41)
# np_2016 shape =  (222, 41)
# np_2017 shape =  (222, 41)

# %% [markdown]
# ### Smush data into [0, 1]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
np_2012_scaled = scaler.fit_transform(np_2012)
np_2013_scaled = scaler.fit_transform(np_2013)
np_2014_scaled = scaler.fit_transform(np_2014)
np_2015_scaled = scaler.fit_transform(np_2015)
np_2016_scaled = scaler.fit_transform(np_2016)
np_2017_scaled = scaler.fit_transform(np_2017)

# %% [markdown]
# ### Split into train and test sets

# %%
import numpy as np
np_X = np.stack([np_2012_scaled, np_2013_scaled, np_2014_scaled, 
                 np_2015_scaled, np_2016_scaled], axis=1)
np_y = np_2017_scaled[:,ops_plus_index]

print('np_X shape = ', np_X.shape)
print('np_y shape = ', np_y.shape)
# Out:
# np_X shape =  (222, 5, 41)
# np_y shape =  (222,)

# %%
player_count, __, __ = np_X.shape
train_size = int(player_count*0.8)

X_train = np_X[:train_size,...]
y_train = np_y[:train_size,...]
X_test = np_X[train_size:,...]
y_test = np_y[train_size:,...]

print('X_train shape = ', X_train.shape)
print('y_train shape = ', y_train.shape)
print('X_test shape = ', X_test.shape)
print('y_test shape = ', y_test.shape)
# Out:
# X_train shape =  (177, 5, 41)
# y_train shape =  (177,)
# X_test shape =  (45, 5, 41)
# y_test shape =  (45,)

# %% [markdown]
# ## RNN with LSTM

# %% [markdown]
# ### Build model

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM
def build_model():
    model = Sequential()
    model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1:])))
    model.add(Dropout(0.2))
    model.add(LSTM(units=50, return_sequences=True))
    model.add(Dropout(0.4))
    model.add(LSTM(units=50, return_sequences=True))
    model.add(Dropout(0.6))
    model.add(LSTM(units=50))
    model.add(Dropout(0.8))
    model.add(Dense(units=1))
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model
    
model = build_model()
model.summary()
# Out:
# WARNING:tensorflow:Large dropout rate: 0.6 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_9 (LSTM)                (None, 5, 50)             18400
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 5, 50)             0
# _________________________________________________________________
# lstm_10 (LSTM)               (None, 5, 50)             20200
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 5, 50)             0
# _________________________________________________________________
# lstm_11 (LSTM)               (None, 5, 50)             20200
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 5, 50)             0
# _________________________________________________________________
# lstm_12 (LSTM)               (None, 50)                20200
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 79,051
# Trainable params: 79,051
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train model

# %%
model.fit(X_train, y_train, epochs=300, batch_size=32)
# Out:
# Epoch 1/300
# 177/177 [==============================] - 2s 10ms/step - loss: 0.0486
# Epoch 2/300
# 177/177 [==============================] - 0s 742us/step - loss: 0.0228
# Epoch 3/300
# 177/177 [==============================] - 0s 715us/step - loss: 0.0233
# Epoch 4/300
# 177/177 [==============================] - 0s 583us/step - loss: 0.0188
# Epoch 5/300
# 177/177 [==============================] - 0s 660us/step - loss: 0.0165
# Epoch 6/300
# 177/177 [==============================] - 0s 652us/step - loss: 0.0135
# Epoch 7/300
# 177/177 [==============================] - 0s 653us/step - loss: 0.0146
# Epoch 8/300
# 177/177 [==============================] - 0s 567us/step - loss: 0.0135
# Epoch 9/300
# 177/177 [==============================] - 0s 612us/step - loss: 0.0132
# Epoch 10/300
# 177/177 [==============================] - 0s 1ms/step - loss: 0.0108
# Epoch
# Epoch 295/300
# 177/177 [==============================] - 0s 494us/step - loss: 0.0049
# Epoch 296/300
# 177/177 [==============================] - 0s 490us/step - loss: 0.0044
# Epoch 297/300
# 177/177 [==============================] - 0s 472us/step - loss: 0.0047
# Epoch 298/300
# 177/177 [==============================] - 0s 465us/step - loss: 0.0047
# Epoch 299/300
# 177/177 [==============================] - 0s 477us/step - loss: 0.0044
# Epoch 300/300
# 177/177 [==============================] - 0s 479us/step - loss: 0.0038

# %% [markdown]
# ### Evaluate model

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
def evaluate(y_pred, y_actual, name):
    print(name)
    print('*'*50)
    print('R2 score = ', r2_score(y_actual, y_pred))
    print('MSE = ', mean_squared_error(y_actual, y_pred))
    print('MAE = ', mean_absolute_error(y_actual, y_pred))
    num_examples = y_actual.shape[0]
    for i in range(num_examples):
        print('Predicted = {}; Actual = {}'.format(y_pred[i,0], y_actual[i]))

# %% [markdown]
# #### Test set

# %%
y_test_pred = model.predict(X_test)
evaluate(y_test_pred, y_test, 'TEST')
# Out:
# TEST
# **************************************************
# R2 score =  -0.5062639376034499
# MSE =  0.0031442587961021877
# MAE =  0.04065630489174179
# Predicted = 0.2906692624092102; Actual = 0.35159855237501586
# Predicted = 0.2437504231929779; Actual = 0.23787307624221282
# Predicted = 0.2419770359992981; Actual = 0.2625763317031632
# Predicted = 0.2791743576526642; Actual = 0.2574209363138247
# Predicted = 0.27782589197158813; Actual = 0.20990268859077602
# Predicted = 0.3683529198169708; Actual = 0.34042660012538434
# Predicted = 0.27537453174591064; Actual = 0.294078899538986
# Predicted = 0.16822883486747742; Actual = 0.31731151354792986
# Predicted = 0.14515769481658936; Actual = 0.23332161862495188
# Predicted = 0.26351916790008545; Actual = 0.20242168451203624
# Predicted = 0.2458108514547348; Actual = 0.24191090149245167
# Predicted = 0.2732093632221222; Actual = 0.2953229624476221
# Predicted = 0.22328302264213562; Actual = 0.20411613340292611
# Predicted = 0.2821258306503296; Actual = 0.2645579974238509
# Predicted = 0.284851998090744; Actual = 0.29087354667795107
# Predicted = 0.25328248739242554; Actual = 0.19120229747382855
# Predicted = 0.3238515257835388; Actual = 0.21590669397780315
# Predicted = 0.25985580682754517; Actual = 0.25063336038148654
# Predicted = 0.23823249340057373; Actual = 0.3281977160230804
# Predicted = 0.28850096464157104; Actual = 0.28185376457804723
# Predicted = 0.26568058133125305; Actual = 0.22074781351705647
# Predicted = 0.24704191088676453; Actual = 0.18168681368299672
# Predicted = 0.22463226318359375; Actual = 0.23671410254195044
# Predicted = 0.26897314190864563; Actual = 0.2861377291092138
# Predicted = 0.30693507194519043; Actual = 0.15158349060709683
# Predicted = 0.2845154404640198; Actual = 0.2727899708186397
# Predicted = 0.2595941126346588; Actual = 0.2827961031098639
# Predicted = 0.319736510515213; Actual = 0.2543376750563757
# Predicted = 0.22574889659881592; Actual = 0.22274594285852145
# Predicted = 0.25857850909233093; Actual = 0.27192310413256443
# Predicted = 0.29073572158813477; Actual = 0.2712352181951373
# Predicted = 0.303104966878891; Actual = 0.2795136483416244
# Predicted = 0.27357789874076843; Actual = 0.22667716208907374
# Predicted = 0.2804013192653656; Actual = 0.23905454479066587
# Predicted = 0.26202723383903503; Actual = 0.2971003814669836
# Predicted = 0.261144757270813; Actual = 0.299072918843478
# Predicted = 0.17795097827911377; Actual = 0.19196728531846022
# Predicted = 0.26335519552230835; Actual = 0.26692598771129267
# Predicted = 0.25988584756851196; Actual = 0.26517367163846284
# Predicted = 0.2726738452911377; Actual = 0.24537250001548558
# Predicted = 0.27447062730789185; Actual = 0.27344150638543974
# Predicted = 0.25306740403175354; Actual = 0.3293896169648973
# Predicted = 0.2836917042732239; Actual = 0.340060651326919
# Predicted = 0.24011826515197754; Actual = 0.2685930515696025
# Predicted = 0.20240941643714905; Actual = 0.33698439933376134

# %%
import matplotlib.pyplot as plt
plt.plot(y_test, color='black', label = 'Actual OPS+ - test')
plt.plot(y_test_pred, color='green', label = 'Predicted OPS+ - test')
plt.title('OPS+ Prediction--Test Set')
plt.xlabel('Player')
plt.ylabel('OPS+')
plt.legend()
plt.show()

# %% [markdown]
# #### Train set

# %%
y_train_pred = model.predict(X_train)
evaluate(y_train_pred, y_train, 'TRAIN')
# Out:
# TRAIN
# **************************************************
# R2 score =  0.49207542678549465
# MSE =  0.0035471409602491925
# MAE =  0.036456339280214176
# Predicted = 0.22500497102737427; Actual = 0.243153008327332
# Predicted = 0.27592507004737854; Actual = 0.27256974951497526
# Predicted = 0.23475494980812073; Actual = 0.15806494099666524
# Predicted = 0.32899343967437744; Actual = 0.3043158485333848
# Predicted = 0.26555106043815613; Actual = 0.2890449437286482
# Predicted = 0.2739922106266022; Actual = 0.30858905465889497
# Predicted = 0.2543833553791046; Actual = 0.18708019804594753
# Predicted = 0.21028611063957214; Actual = 0.2433898562579201
# Predicted = 0.2739311158657074; Actual = 0.32520003299244404
# Predicted = 0.2558601200580597; Actual = 0.22364003157103043
# Predicted = 0.26082316040992737; Actual = 0.24038516396299242
# Predicted = 0.24215567111968994; Actual = 0.21722247959081545
# Predicted = 0.24185577034950256; Actual = 0.17228787928677639
# Predicted = 0.26550763845443726; Actual = 0.2647425203814735
# Predicted = 0.2637135982513428; Actual = 0.212038721132019
# Predicted = 0.26001814007759094; Actual = 0.28061736295828776
# Predicted = 0.18843725323677063; Actual = 0.191925066726566
# Predicted = 0.23880665004253387; Actual = 0.2707233788957247
# Predicted = 0.265913188457489; Actual = 0.27647162763919175
# Predicted = 0.34048593044281006; Actual = 0.3096003447906007
# Predicted = 0.2805461585521698; Actual = 0.21803881437153472
# Predicted = 0.19705817103385925; Actual = 0.06947664268628913
# Predicted = 0.3515787124633789; Actual = 0.32232884273134405
# Predicted = 0.24995164573192596; Actual = 0.28836928325219435
# Predicted = 0.2401622086763382; Actual = 0.3143806630372805
# Predicted = 0.25585615634918213; Actual = 0.333924121942942
# Predicted = 0.22234538197517395; Actual = 0.23536930183489502
# Predicted = 0.26300689578056335; Actual = 0.2377462574603838
# Predicted = 0.3127437233924866; Actual = 0.29741742842155605
# Predicted = 0.24895168840885162; Actual = 0.24854231753662506
# Predicted = 0.26085180044174194; Actual = 0.3220188050410629
# Predicted = 0.2375260889530182; Actual = 0.1896517830101302
# Predicted = 0.23979860544204712; Actual = 0.18907164413541377
# Predicted = 0.28568077087402344; Actual = 0.32346124642975793
# Predicted = 0.30248144268989563; Actual = 0.353616242454038
# Predicted = 0.28783872723579407; Actual = 0.33209111782768885
# Predicted = 0.27946391701698303; Actual = 0.26837804646262
# Predicted = 0.24919365346431732; Actual = 0.1719458923918185
# Predicted = 0.2756589651107788; Actual = 0.26658318578560325
# Predicted = 0.2537018954753876; Actual = 0.31763410271147685
# Predicted = 0.2954871356487274; Actual = 0.2865737705505924
# Predicted = 0.2328130006790161; Actual = 0.18220370617294496
# Predicted = 0.30956733226776123; Actual = 0.24472797371297683
# Predicted = 0.3104441165924072; Actual = 0.3256279241265071
# Predicted = 0.27607840299606323; Actual = 0.31544264808048855
# Predicted = 0.2769767642021179; Actual = 0.29405542665391743
# Predicted = 0.2916226387023926; Actual = 0.3239360833339582
# Predicted = 0.302439421415329; Actual = 0.26222603149474355
# Predicted = 0.2961328327655792; Actual = 0.28535106144712297
# Predicted = 0.20393085479736328; Actual = 0.2775295375287421
# Predicted = 0.23364174365997314; Actual = 0.245816854770326
# Predicted = 0.22747144103050232; Actual = 0.2285783027734844
# Predicted = 0.256001740694046; Actual = 0.22808520918089736
# Predicted = 0.27044329047203064; Actual = 0.34701041837483526
# Predicted = 0.26531606912612915; Actual = 0.3028628117451797
# Predicted = 0.3183797597885132; Actual = 0.30502883741734366
# Predicted = 0.2534988522529602; Actual = 0.26363130748207997
# Predicted = 0.25473660230636597; Actual = 0.27436183908750467
# Predicted = 0.25342074036598206; Actual = 0.21091283767945757
# Predicted = 0.27097439765930176; Actual = 0.3015851695704038
# Predicted = 0.2821030020713806; Actual = 0.28463187832960435
# Predicted = 0.29832160472869873; Actual = 0.28575173055475234
# Predicted = 0.27807170152664185; Actual = 0.3408422657984742
# Predicted = 0.27720877528190613; Actual = 0.20841965867164988
# Predicted = 0.2833927571773529; Actual = 0.2615014691743967
# Predicted = 0.22261783480644226; Actual = 0.2846199788809237
# Predicted = 0.2450944036245346; Actual = 0.21179649399860273
# Predicted = 0.18334618210792542; Actual = 0.18449329050401175
# Predicted = 0.2591429054737091; Actual = 0.30028160941836474
# Predicted = 0.261532723903656; Actual = 0.2399973723409215
# Predicted = 0.3727511167526245; Actual = 0.413017312230775
# Predicted = 0.27453577518463135; Actual = 0.27158242128677706
# Predicted = 0.27971839904785156; Actual = 0.3065089332258362

# %%
import matplotlib.pyplot as plt
plt.plot(y_train, color='black', label = 'Actual OPS+ - train')
plt.plot(y_train_pred, color='green', label = 'Predicted OPS+ - train')
plt.title('OPS+ Prediction--Train Set')
plt.xlabel('Player')
plt.ylabel('OPS+')
plt.legend()
plt.show()

# %% [markdown]
# #### Feature importance chart (IN PROGRESS)

# %%
cols_to_descriptions = {
    'age': 'Player age',
    'mlb_ID': 'Player ID number',
    'PA': 'Plate appearances',
    'Inn': 'Innings played in field',
    'runs_bat': 'Batting runs from modified wRAA',
    'runs_br': 'Baserunning runs (includes SB and CS runs)',
    'runs_dp': 'Runs from avoiding GIDP\'s in DP situation GB\'s',
    'runs_field': 'Total fielding runs from TZR and DRS',
    'runs_infield': 'Defensive DP-turn runs',
    'runs_outfield': 'Outfield arm ratings',
    'runs_catcher': 'Catcher defense',
    'runs_good_plays': 'Superlative defensive plays',
    'runs_defense': 'Overall defensive ability',
    'runs_position': 'Runs from the position played (non-pitching)',
    'runs_position_p': 'Position runs after zeroing negative contribution of pitcher offense',
    'runs_replacement': 'Replacement level adjustment for the league',
    'runs_above_rep': 'Sum of the other runs-related statistics (excludes double-counting)',
    'runs_above_avg': 'Sum of the other runs-related statistics without replacement level runs',
    'runs_above_avg_off': 'Sum of the other runs-related statistics without defense',
    'runs_above_avg_def': 'Runs from defense plus position',
    'WAA': 'Wins above average',
    'WAA_off': 'Offensive wins above average',
    'WAA_def': 'Defensive wins above average',
    'WAR': 'Wins above replacement',
    'WAR_def': 'Defensive wins above replacement',
    'WAR_off': 'Offensive wins above replacement',
    'WAR_rep': 'WAR attributable to replacement level',
    'salary': 'Annual player salary',
    'Pitcher': 'Whether the player is a pitcher or position player',
    'teamRpG': 'Average team runs scored with this player',
    'oppRpG': 'Average team runs allowed with this player',
    'oppRpPA_rep': 'Average team runs allowed per PA by a replacement player',
    'oppRpG_rep': 'Average team runs allowed per game by a replacement player',
    'pyth_exponent': 'Pythagenpat exponent based on a run environment for average teams',
    'pyth_exponent_rep': 'Pythagenpat exponent based on a run environment for a replacement player',
    'waa_win_perc': 'Win percentage using pythagenpat exponent and team and opp R/G',
    'waa_win_perc_off': 'Offensive win percentage using pythagenpat exponent and team and opp R/G',
    'waa_win_perc_def': 'Defensive win percentage using pythagenpat exponent and team and opp R/G',
    'waa_win_perc_rep': 'How a replacement player would do',
    'OPS_plus': 'Adjusted on-base percentage plus slugging percentage',
    'TOB_lg': 'Cumulative total number of times a player has reached base',
    'TB_lg': 'Total number of bases that a player has gained through hits'
}
col_descriptions = [cols_to_descriptions[c] for c in cols_to_indexes.keys()]

# %%
from keras.wrappers.scikit_learn import KerasRegressor
from eli5 import show_prediction
regressor = KerasRegressor(build_fn=build_model)
regressor.fit(X_test, y_test)    

perm = PermutationImportance(regressor, random_state=1).fit(X_test,y_test)
eli5.show_weights(perm, feature_names=col_descriptions)
# Out:
# Epoch 1/1
# 45/45 [==============================] - 2s 35ms/step - loss: 0.0706
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-101-c49f711030b4> in <module>
#       4 regressor.fit(X_test, y_test)
#       5
# ----> 6 perm = PermutationImportance(regressor, random_state=1).fit(X_test,y_test)
#       7 eli5.show_weights(perm, feature_names=col_descriptions)
#       8
#
# ~/CS229-Final-Project/venv/lib/python3.7/site-packages/eli5/sklearn/permutation_importance.py in fit(self, X, y, groups, **fit_params)
#     195             self.estimator_.fit(X, y, **fit_params)
#     196
# --> 197         X = check_array(X)
#     198
#     199         if self.cv not in (None, "prefit"):
#
# ~/CS229-Final-Project/venv/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     556         if not allow_nd and array.ndim >= 3:
#     557             raise ValueError("Found array with dim %d. %s expected <= 2."
# --> 558                              % (array.ndim, estimator_name))
#     559
#     560         if force_all_finite:
#
# ValueError: Found array with dim 3. Estimator expected <= 2.
